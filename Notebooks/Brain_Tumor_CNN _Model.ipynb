# %% [markdown]
# ## Brain Tumor Prediction Model

# %%
# !ls /kaggle/input/datasets/navoneel/brain-mri-images-for-brain-tumor-detection
# Out:
# brain_tumor_dataset  no  yes

# %%
target_names = ["yes","no"]

# %% [markdown]
# # Visualizing One Image

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
img_yes = Image.open("/kaggle/input/datasets/navoneel/brain-mri-images-for-brain-tumor-detection/yes/Y1.jpg")
img_yes
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=180x218>

# %%
from torchvision import transforms

# %%
transforms = transforms.ToTensor()

img_yes_tensors = transforms(img_yes)
img_yes_tensors
# Out:
# tensor([[[0.0118, 0.0118, 0.0118,  ..., 0.0078, 0.0078, 0.0078],
#          [0.0118, 0.0118, 0.0118,  ..., 0.0078, 0.0078, 0.0078],
#          [0.0118, 0.0118, 0.0118,  ..., 0.0078, 0.0078, 0.0078],
#          ...,
#          [0.0078, 0.0078, 0.0078,  ..., 0.0078, 0.0118, 0.0118],
#          [0.0078, 0.0078, 0.0078,  ..., 0.0039, 0.0039, 0.0078],
#          [0.0078, 0.0078, 0.0078,  ..., 0.0039, 0.0039, 0.0078]],
#
#         [[0.0118, 0.0118, 0.0118,  ..., 0.0078, 0.0078, 0.0078],
#          [0.0118, 0.0118, 0.0118,  ..., 0.0078, 0.0078, 0.0078],
#          [0.0118, 0.0118, 0.0118,  ..., 0.0078, 0.0078, 0.0078],
#          ...,
#          [0.0078, 0.0078, 0.0078,  ..., 0.0078, 0.0118, 0.0118],
#          [0.0078, 0.0078, 0.0078,  ..., 0.0039, 0.0039, 0.0078],
#          [0.0078, 0.0078, 0.0078,  ..., 0.0039, 0.0039, 0.0078]],
#
#         [[0.0118, 0.0118, 0.0118,  ..., 0.0078, 0.0078, 0.0078],
#          [0.0118, 0.0118, 0.0118,  ..., 0.0078, 0.0078, 0.0078],
# ...

# %%
img_yes_tensors.shape
# Out:
# torch.Size([3, 218, 180])
