# %% [markdown]
# # Crop Recommendation Model

# %% [markdown]
# ## Load Data

# %%
import pandas as pd

# %%
data = pd.read_csv("Datasets/Crop_recommendation.csv")
data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   str
# dtypes: float64(4), int64(3), str(1)
# memory usage: 137.6 KB

# %%
# set example
a = {1, 2, 3, 1, 1, 2, 4}
a
# Out:
# {1, 2, 3, 4}

# %%
label_names = list(set(data["label"]))
label_names
# Out:
# ['cotton',
#  'rice',
#  'papaya',
#  'grapes',
#  'muskmelon',
#  'apple',
#  'watermelon',
#  'pigeonpeas',
#  'mungbean',
#  'chickpea',
#  'kidneybeans',
#  'coffee',
#  'mango',
#  'mothbeans',
#  'lentil',
#  'maize',
#  'pomegranate',
#  'coconut',
#  'blackgram',
#  'orange',
#  'jute',
#  'banana']

# %%
len(label_names)
# Out:
# 22

# %%
data
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %% [markdown]
# # Feature
# - Split our data into input and output values
# - Input values will be stored in X and output values will be stored in y variables.

# %%
data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
X = data.drop(["label"], axis=1)
y = data["label"]

# %%
X.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340

# %%
y.head()
# Out:
# 0    rice
# 1    rice
# 2    rice
# 3    rice
# 4    rice
# Name: label, dtype: str

# %%
X.shape, y.shape
# Out:
# ((2200, 7), (2200,))

# %% [markdown]
# - Let's convert 'y' variable into integer data type.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

y = le.fit_transform(y)
y[:5]
# Out:
# array([20, 20, 20, 20, 20])

# %% [markdown]
# - Lets convert our data variables `X` and `y` into pytorch tensors.

# %%
import torch

# %%
X_tensors = torch.tensor(X.values, dtype=torch.float)
y_tensors = torch.tensor(y, dtype=torch.long)

# %%
X_tensors, X_tensors.ndim, X_tensors.shape
# Out:
# (tensor([[ 90.0000,  42.0000,  43.0000,  ...,  82.0027,   6.5030, 202.9355],
#          [ 85.0000,  58.0000,  41.0000,  ...,  80.3196,   7.0381, 226.6555],
#          [ 60.0000,  55.0000,  44.0000,  ...,  82.3208,   7.8402, 263.9642],
#          ...,
#          [118.0000,  33.0000,  30.0000,  ...,  67.2251,   6.3626, 173.3228],
#          [117.0000,  32.0000,  34.0000,  ...,  52.1274,   6.7588, 127.1753],
#          [104.0000,  18.0000,  30.0000,  ...,  60.3965,   6.7798, 140.9370]]),
#  2,
#  torch.Size([2200, 7]))

# %%
y_tensors, y_tensors.ndim, y_tensors.shape
# Out:
# (tensor([20, 20, 20,  ...,  5,  5,  5]), 1, torch.Size([2200]))

# %% [markdown]
# ## Train test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_tensors, y_tensors, test_size=0.2, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# (torch.Size([1760, 7]),
#  torch.Size([440, 7]),
#  torch.Size([1760]),
#  torch.Size([440]))

# %% [markdown]
# # Model training

# %%
import torch.nn as nn

# %%
class CropRecommendationModel(nn.Module):
    def __init__(self):
        super(CropRecommendationModel, self).__init__()

        # layers
        self.fc1 = nn.Linear(7, 14)
        # ------ hidden layer
        self.fc2 = nn.Linear(14, 28)
        self.fc3 = nn.Linear(28, 56)
        self.fc4 = nn.Linear(56, 34)
        # -------
        self.fc5 = nn.Linear(34, 22) # output layer

    def forward(self, x):
        x = self.fc1(x) # input layer

        # hidden layer
        x = self.fc2(x)
        x = self.fc3(x)
        x = self.fc4(x)

        x = self.fc5(x) # output layer

    def forward(self, x):
        x = self.fc1(x) # input layer 
        
        # Hidden layer
        x = self.fc2(x)
        x = self.fc3(x)
        x = self.fc4(x)

        x = self.fc5(x) # output layer

        return x

# %%
model = CropRecommendationModel()

# %%
model
# Out:
# CropRecommendationModel(
#   (fc1): Linear(in_features=7, out_features=14, bias=True)
#   (fc2): Linear(in_features=14, out_features=28, bias=True)
#   (fc3): Linear(in_features=28, out_features=56, bias=True)
#   (fc4): Linear(in_features=56, out_features=34, bias=True)
#   (fc5): Linear(in_features=34, out_features=22, bias=True)
# )

# %%
loss_function = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
# Training loop 
epoches = 100

for epoch in range(epoches):
    model.train()

    out = model(X_tensors)
    loss = loss_function(out, y_tensors.long().squeeze())

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if epoch % 10 == 0 :
        print("Epoch: ", epoch, "Loss value: ", loss.item())
# Out:
# Epoch:  0 Loss value:  8.878954887390137
# Epoch:  10 Loss value:  2.9194064140319824
# Epoch:  20 Loss value:  2.101060628890991
# Epoch:  30 Loss value:  1.6371562480926514
# Epoch:  40 Loss value:  1.3632235527038574
# Epoch:  50 Loss value:  1.1494251489639282
# Epoch:  60 Loss value:  0.9766015410423279
# Epoch:  70 Loss value:  0.8363673090934753
# Epoch:  80 Loss value:  0.7229306697845459
# Epoch:  90 Loss value:  0.6321389079093933

# %%
y_pred = model(X_test).argmax(dim=1)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8386363636363636

# %% [markdown]
# # Implement on wandb

# %%
import wandb

# %%
model = CropRecommendationModel()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
run = wandb.init(
    # Set the wandb entity where your project will be logged (generally your team name).
    entity="aishwaryapatil845-aish-com",
    # Set the wandb project where this run will be logged.
    project="Crop_Recommendation",
    name="Model-epoch-100",
    # Track hyperparameters and run metadata.
    config={
        "learning_rate": 0.001,
        "architecture": "FNN",
        "dataset": "crop_recommndation",
        "epochs": 100,
    },
)

# Training loop 
epoches = 100

for epoch in range(epoches):
    model.train()

    out = model(X_tensors)
    loss = loss_function(out, y_tensors.long().squeeze())

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # accuracy
    model.eval()
    y_pred = model(X_test).argmax(dim=1)
    acc = accuracy_score(y_test, y_pred)

    if epoch % 10 == 0 :
        print("Epoch: ", epoch, "Loss value: ", loss.item())
        run.log({"loss": loss.item(), "epoch": epoch, "accuracy": acc})
# Out:
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/aishwarya/.netrc.
# wandb: Currently logged in as: aishwaryapatil845 (aishwaryapatil845-aish-com) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/home/aishwarya/Downloads/Notes/PyTorch_Notes/Notebooks/wandb/run-20260306_123924-m2p79a1s</code>
# Syncing run <strong><a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation/runs/m2p79a1s' target="_blank">Model-epoch-100</a></strong> to <a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation' target="_blank">https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation</a>
#  View run at <a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation/runs/m2p79a1s' target="_blank">https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation/runs/m2p79a1s</a>
# Epoch:  0 Loss value:  9.31525707244873
# Epoch:  10 Loss value:  3.140000343322754
# Epoch:  20 Loss value:  2.2627012729644775
# Epoch:  30 Loss value:  1.8019658327102661
# Epoch:  40 Loss value:  1.4659464359283447
# Epoch:  50 Loss value:  1.2216438055038452
# Epoch:  60 Loss value:  1.0205583572387695
# Epoch:  70 Loss value:  0.8522229194641113
# Epoch:  80 Loss value:  0.7160545587539673
# Epoch:  90 Loss value:  0.6083643436431885

# %% [markdown]
# ### Using ReLU activation function

# %%
class CropRecommendationModelReLU(nn.Module):
    def __init__(self):
        super(CropRecommendationModelReLU, self).__init__()

        # layers
        self.fc1 = nn.Linear(7, 14)
        self.relu1 = nn.ReLU()
        
        # ------ hidden layer
        self.fc2 = nn.Linear(14, 28)
        self.relu2 = nn.ReLU()
        self.do1 = nn.Dropout(0.2)
        
        self.fc3 = nn.Linear(28, 56)
        self.relu3 = nn.ReLU()
        self.do2 = nn.Dropout(0.2)
        
        self.fc4 = nn.Linear(56, 34)
        self.relu4 = nn.ReLU()
        self.do3 = nn.Dropout(0.1)
        # -------
        self.fc5 = nn.Linear(34, 22) # output layer

    def forward(self, x):
        x = self.fc1(x) # input layer
        x = self.relu1(x)
        

        # hidden layer
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.do1(x)
        
        x = self.fc3(x)
        x = self.relu3(x)
        x = self.do2(x)
        
        x = self.fc4(x)
        x = self.relu4(x)
        x = self.do3(x)

        x = self.fc5(x) # output layer

        return x

# %%
model = CropRecommendationModelReLU()

# %%
model
# Out:
# CropRecommendationModelReLU(
#   (fc1): Linear(in_features=7, out_features=14, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=14, out_features=28, bias=True)
#   (relu2): ReLU()
#   (do1): Dropout(p=0.2, inplace=False)
#   (fc3): Linear(in_features=28, out_features=56, bias=True)
#   (relu3): ReLU()
#   (do2): Dropout(p=0.2, inplace=False)
#   (fc4): Linear(in_features=56, out_features=34, bias=True)
#   (relu4): ReLU()
#   (do3): Dropout(p=0.1, inplace=False)
#   (fc5): Linear(in_features=34, out_features=22, bias=True)
# )

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
run = wandb.init(
    # Set the wandb entity where your project will be logged (generally your team name).
    entity="aishwaryapatil845-aish-com",
    # Set the wandb project where this run will be logged.
    project="Crop_Recommendation",
    name="Model-epoch-500-relu-dropout",
    # Track hyperparameters and run metadata.
    config={
        "learning_rate": 0.001,
        "architecture": "FNN",
        "dataset": "crop_recommndation",
        "epochs": 500,
    },
)

# Training loop 
epoches = 500

for epoch in range(epoches):
    model.train()

    out = model(X_tensors)
    loss = loss_function(out, y_tensors)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # accuracy
    model.eval()
    y_pred = model(X_test).argmax(dim=1)
    acc = accuracy_score(y_test, y_pred)

    if epoch % 10 == 0 :
        print("Epoch: ", epoch, "Loss value: ", loss.item())
        run.log({"loss": loss.item(), "epoch": epoch, "accuracy": acc})
# Out:
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▃▃▄▅▆▇▇██</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>loss</td><td>█▃▂▂▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.83864</td></tr><tr><td>epoch</td><td>90</td></tr><tr><td>loss</td><td>0.60836</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Model-epoch-100</strong> at: <a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation/runs/m2p79a1s' target="_blank">https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation/runs/m2p79a1s</a><br> View project at: <a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation' target="_blank">https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260306_123924-m2p79a1s/logs</code>
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/home/aishwarya/Downloads/Notes/PyTorch_Notes/Notebooks/wandb/run-20260306_123930-ym83kk00</code>
# Syncing run <strong><a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation/runs/ym83kk00' target="_blank">Model-epoch-500-relu-dropout</a></strong> to <a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation' target="_blank">https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation</a>
#  View run at <a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation/runs/ym83kk00' target="_blank">https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation/runs/ym83kk00</a>
# Epoch:  0 Loss value:  3.3611056804656982
# Epoch:  10 Loss value:  2.91513729095459
# Epoch:  20 Loss value:  2.673192262649536
# Epoch:  30 Loss value:  2.377135753631592
# Epoch:  40 Loss value:  2.0668821334838867
# Epoch:  50 Loss value:  1.8262720108032227
# Epoch:  60 Loss value:  1.6366795301437378
# Epoch:  70 Loss value:  1.4706857204437256
# Epoch:  80 Loss value:  1.3549813032150269
# Epoch:  90 Loss value:  1.2009940147399902
# Epoch:  100 Loss value:  1.1459907293319702
# Epoch:  110 Loss value:  1.0935158729553223
# Epoch:  120 Loss value:  1.0327879190444946
# Epoch:  130 Loss value:  0.962049126625061
# Epoch:  140 Loss value:  0.9229065179824829
# Epoch:  150 Loss value:  0.9002360701560974
# Epoch:  160 Loss value:  0.8217368125915527
# Epoch:  170 Loss value:  0.7926322221755981
# Epoch:  180 Loss value:  0.7458497285842896
# Epoch:  190 Loss value:  0.7337234020233154
# Epoch:  200 Loss value:  0.6851602792739868
# Epoch:  210 Loss value:  0.6345052719116211
# Epoch:  220 Loss value:  0.6353235244750977
# Epoch:  230 Loss value:  0.6242120862007141
# Epoch:  240 Loss value:  0.580241322517395
# Epoch:  250 Loss value:  0.540026843547821
# Epoch:  260 Loss value:  0.5732385516166687
# Epoch:  270 Loss value:  0.5649241209030151
# Epoch:  280 Loss value:  0.5060606598854065
# Epoch:  290 Loss value:  0.4952446520328522
# Epoch:  300 Loss value:  0.4745117127895355
# Epoch:  310 Loss value:  0.4762956202030182
# Epoch:  320 Loss value:  0.4449099898338318
# Epoch:  330 Loss value:  0.44770973920822144
# Epoch:  340 Loss value:  0.41723009943962097
# Epoch:  350 Loss value:  0.4314541518688202
# Epoch:  360 Loss value:  0.39645645022392273
# Epoch:  370 Loss value:  0.4004610776901245
# Epoch:  380 Loss value:  0.42791447043418884
# Epoch:  390 Loss value:  0.39627015590667725
# Epoch:  400 Loss value:  0.37634479999542236
# Epoch:  410 Loss value:  0.3817584812641144
# Epoch:  420 Loss value:  0.36668431758880615
# Epoch:  430 Loss value:  0.3484231233596802
# Epoch:  440 Loss value:  0.37024298310279846
# Epoch:  450 Loss value:  0.34893685579299927
# Epoch:  460 Loss value:  0.3559054136276245
# Epoch:  470 Loss value:  0.33497175574302673
# Epoch:  480 Loss value:  0.33975037932395935
# Epoch:  490 Loss value:  0.3556019067764282

# %% [markdown]
# # Data Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(X_tensors)
X_scaled
# Out:
# array([[ 1.0687974 , -0.34455075, -0.1016875 , ...,  0.47266656,
#          0.04330197,  1.81036042],
#        [ 0.93332887,  0.14061552, -0.14118477, ...,  0.39705111,
#          0.73487264,  2.24205783],
#        [ 0.25598625,  0.04964684, -0.08193887, ...,  0.4869538 ,
#          1.7715104 ,  2.92106578],
#        ...,
#        [ 1.82742114, -0.61745677, -0.35841972, ..., -0.19123529,
#         -0.13812017,  1.27141778],
#        [ 1.80032743, -0.64777967, -0.27942519, ..., -0.86951795,
#          0.37390363,  0.43154519],
#        [ 1.44810927, -1.07230015, -0.35841972, ..., -0.49802014,
#          0.40109603,  0.68200519]], shape=(2200, 7))

# %%
X_scaled_tensors = torch.tensor(X_scaled, dtype=torch.float)

# %% [markdown]
# - Now we have scaled our data .
# - Lets apply train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled_tensors, y_tensors, test_size=0.2, random_state=42)

# %%
model = CropRecommendationModelReLU()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
run = wandb.init(
    # Set the wandb entity where your project will be logged (generally your team name).
    entity="aishwaryapatil845-aish-com",
    # Set the wandb project where this run will be logged.
    project="Crop_Recommendation",
    name="Model-epoch-500-scaled-data-new",
    # Track hyperparameters and run metadata.
    config={
        "learning_rate": 0.001,
        "architecture": "FNN",
        "dataset": "crop_recommndation",
        "epochs": 500,
    },
)

# Training loop 
epoches = 500

for epoch in range(epoches):
    model.train()

    out = model(X_train)
    loss = loss_function(out, y_train)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # accuracy
    model.eval()
    y_pred = model(X_test).argmax(dim=1)
    acc = accuracy_score(y_test, y_pred)

    if epoch % 10 == 0 :
        print("Epoch: ", epoch, "Loss value: ", loss.item())
        run.log({"loss": loss.item(), "epoch": epoch, "accuracy": acc})
# Out:
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▂▃▄▅▆▆▆▆▇▇▇▇▇▇▇▇███████████████████████</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇██</td></tr><tr><td>loss</td><td>█▇▆▆▅▄▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.93864</td></tr><tr><td>epoch</td><td>490</td></tr><tr><td>loss</td><td>0.3556</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Model-epoch-500-relu-dropout</strong> at: <a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation/runs/ym83kk00' target="_blank">https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation/runs/ym83kk00</a><br> View project at: <a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation' target="_blank">https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260306_123930-ym83kk00/logs</code>
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/home/aishwarya/Downloads/Notes/PyTorch_Notes/Notebooks/wandb/run-20260306_123940-n2isvifb</code>
# Syncing run <strong><a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation/runs/n2isvifb' target="_blank">Model-epoch-500-scaled-data-new</a></strong> to <a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation' target="_blank">https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation</a>
#  View run at <a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation/runs/n2isvifb' target="_blank">https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation/runs/n2isvifb</a>
# Epoch:  0 Loss value:  3.092421770095825
# Epoch:  10 Loss value:  3.0738091468811035
# Epoch:  20 Loss value:  3.0420870780944824
# Epoch:  30 Loss value:  2.974956750869751
# Epoch:  40 Loss value:  2.8483693599700928
# Epoch:  50 Loss value:  2.6604607105255127
# Epoch:  60 Loss value:  2.436279535293579
# Epoch:  70 Loss value:  2.208395004272461
# Epoch:  80 Loss value:  1.9824732542037964
# Epoch:  90 Loss value:  1.7815877199172974
# Epoch:  100 Loss value:  1.635197639465332
# Epoch:  110 Loss value:  1.5291986465454102
# Epoch:  120 Loss value:  1.3977710008621216
# Epoch:  130 Loss value:  1.28412663936615
# Epoch:  140 Loss value:  1.2241555452346802
# Epoch:  150 Loss value:  1.112443447113037
# Epoch:  160 Loss value:  1.02720308303833
# Epoch:  170 Loss value:  0.9277424812316895
# Epoch:  180 Loss value:  0.866072416305542
# Epoch:  190 Loss value:  0.8120380640029907
# Epoch:  200 Loss value:  0.771253228187561
# Epoch:  210 Loss value:  0.7209464311599731
# Epoch:  220 Loss value:  0.7218647599220276
# Epoch:  230 Loss value:  0.6774457097053528
# Epoch:  240 Loss value:  0.6419382691383362
# Epoch:  250 Loss value:  0.6343849897384644
# Epoch:  260 Loss value:  0.6140629649162292
# Epoch:  270 Loss value:  0.5727109313011169
# Epoch:  280 Loss value:  0.5545496344566345
# Epoch:  290 Loss value:  0.5591791868209839
# Epoch:  300 Loss value:  0.5442107915878296
# Epoch:  310 Loss value:  0.5300744771957397
# Epoch:  320 Loss value:  0.49989253282546997
# Epoch:  330 Loss value:  0.4865375757217407
# Epoch:  340 Loss value:  0.4602050185203552
# Epoch:  350 Loss value:  0.45338404178619385
# Epoch:  360 Loss value:  0.42935165762901306
# Epoch:  370 Loss value:  0.4394163191318512
# Epoch:  380 Loss value:  0.41361042857170105
# Epoch:  390 Loss value:  0.4173223674297333
# Epoch:  400 Loss value:  0.43271708488464355
# Epoch:  410 Loss value:  0.4015471339225769
# Epoch:  420 Loss value:  0.39593467116355896
# Epoch:  430 Loss value:  0.3566282391548157
# Epoch:  440 Loss value:  0.39037656784057617
# Epoch:  450 Loss value:  0.33897048234939575
# Epoch:  460 Loss value:  0.34792324900627136
# Epoch:  470 Loss value:  0.309848427772522
# Epoch:  480 Loss value:  0.32976430654525757
# Epoch:  490 Loss value:  0.3036094307899475

# %% [markdown]
# ## Increase hidden layer

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled_tensors, y_tensors, test_size=0.2, random_state=42)

# %%
class CropRecommendationModelMoreNeurons(nn.Module):
    def __init__(self):
        super(CropRecommendationModelMoreNeurons, self).__init__()

        # layers
        self.fc1 = nn.Linear(7, 14)
        self.relu1 = nn.ReLU()
        
        # ------ hidden layer
        self.fc2 = nn.Linear(14, 28)
        self.relu2 = nn.ReLU()
        self.do1 = nn.Dropout(0.2)
        
        self.fc3 = nn.Linear(28, 56)
        self.relu3 = nn.ReLU()
        self.do2 = nn.Dropout(0.2)
        
        self.fc4 = nn.Linear(56, 112)
        self.relu4 = nn.ReLU()
        self.do3 = nn.Dropout(0.2)
        # -------
        self.fc5 = nn.Linear(112, 56) 
        self.relu5 = nn.ReLU()
        self.do4 = nn.Dropout(0.1)

        self.fc6 = nn.Linear(56, 34)
        self.relu6 = nn.ReLU()
        self.do5 = nn.Dropout(0.1)

        # ------
        self.fc7 = nn.Linear(34, 22) # output layer
        
    def forward(self, x):
        x = self.fc1(x) # input layer
        x = self.relu1(x)
        

        # hidden layer
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.do1(x)
        
        x = self.fc3(x)
        x = self.relu3(x)
        x = self.do2(x)
        
        x = self.fc4(x)
        x = self.relu4(x)
        x = self.do3(x)

        x = self.fc5(x)
        x = self.relu5(x)
        x = self.do4(x)

        x = self.fc6(x)
        x = self.relu6(x)
        x = self.do5(x)

        x = self.fc7(x) # output layer

        return x

# %%
model = CropRecommendationModelMoreNeurons()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
run = wandb.init(
    # Set the wandb entity where your project will be logged (generally your team name).
    entity="aishwaryapatil845-aish-com",
    # Set the wandb project where this run will be logged.
    project="Crop_Recommendation",
    name="Model-epoch-500-more-neurons",
    # Track hyperparameters and run metadata.
    config={
        "learning_rate": 0.001,
        "architecture": "FNN",
        "dataset": "crop_recommndation",
        "epochs": 500,
    },
)

# Training loop 
epoches = 500

for epoch in range(epoches):
    model.train()

    out = model(X_train)
    loss = loss_function(out, y_train)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # accuracy
    model.eval()
    y_pred = model(X_test).argmax(dim=1)
    acc = accuracy_score(y_test, y_pred)

    if epoch % 10 == 0 :
        print("Epoch: ", epoch, "Loss value: ", loss.item())
        run.log({"loss": loss.item(), "epoch": epoch, "accuracy": acc})
# Out:
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▁▂▂▂▃▄▅▅▆▆▇▇▇▇▇▇███████████████████████</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>████▇▆▅▅▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.94318</td></tr><tr><td>epoch</td><td>490</td></tr><tr><td>loss</td><td>0.30361</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Model-epoch-500-scaled-data-new</strong> at: <a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation/runs/n2isvifb' target="_blank">https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation/runs/n2isvifb</a><br> View project at: <a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation' target="_blank">https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260306_123940-n2isvifb/logs</code>
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/home/aishwarya/Downloads/Notes/PyTorch_Notes/Notebooks/wandb/run-20260306_123948-aosnuam5</code>
# Syncing run <strong><a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation/runs/aosnuam5' target="_blank">Model-epoch-500-more-neurons</a></strong> to <a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation' target="_blank">https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation</a>
#  View run at <a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation/runs/aosnuam5' target="_blank">https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation/runs/aosnuam5</a>
# Epoch:  0 Loss value:  3.098057985305786
# Epoch:  10 Loss value:  3.086609125137329
# Epoch:  20 Loss value:  3.0460453033447266
# Epoch:  30 Loss value:  2.9059667587280273
# Epoch:  40 Loss value:  2.650160551071167
# Epoch:  50 Loss value:  2.390608072280884
# Epoch:  60 Loss value:  2.126918077468872
# Epoch:  70 Loss value:  1.8408361673355103
# Epoch:  80 Loss value:  1.6406961679458618
# Epoch:  90 Loss value:  1.398672342300415
# Epoch:  100 Loss value:  1.2572458982467651
# Epoch:  110 Loss value:  1.1190067529678345
# Epoch:  120 Loss value:  1.0295072793960571
# Epoch:  130 Loss value:  0.9510139226913452
# Epoch:  140 Loss value:  0.9158233404159546
# Epoch:  150 Loss value:  0.8625760078430176
# Epoch:  160 Loss value:  0.8264829516410828
# Epoch:  170 Loss value:  0.7359643578529358
# Epoch:  180 Loss value:  0.7268385887145996
# Epoch:  190 Loss value:  0.6998481750488281
# Epoch:  200 Loss value:  0.6633797287940979
# Epoch:  210 Loss value:  0.6256534457206726
# Epoch:  220 Loss value:  0.5862194299697876
# Epoch:  230 Loss value:  0.5704739093780518
# Epoch:  240 Loss value:  0.5261526107788086
# Epoch:  250 Loss value:  0.5290842056274414
# Epoch:  260 Loss value:  0.506589412689209
# Epoch:  270 Loss value:  0.5001280903816223
# Epoch:  280 Loss value:  0.4714016318321228
# Epoch:  290 Loss value:  0.46178704500198364
# Epoch:  300 Loss value:  0.4670126736164093
# Epoch:  310 Loss value:  0.4251537621021271
# Epoch:  320 Loss value:  0.4264151453971863
# Epoch:  330 Loss value:  0.3842901289463043
# Epoch:  340 Loss value:  0.3558569550514221
# Epoch:  350 Loss value:  0.3646141290664673
# Epoch:  360 Loss value:  0.37207862734794617
# Epoch:  370 Loss value:  0.34974420070648193
# Epoch:  380 Loss value:  0.32813313603401184
# Epoch:  390 Loss value:  0.343215674161911
# Epoch:  400 Loss value:  0.2889246642589569
# Epoch:  410 Loss value:  0.3154790997505188
# Epoch:  420 Loss value:  0.29590824246406555
# Epoch:  430 Loss value:  0.30784884095191956
# Epoch:  440 Loss value:  0.3246590793132782
# Epoch:  450 Loss value:  0.2766059935092926
# Epoch:  460 Loss value:  0.27940842509269714
# Epoch:  470 Loss value:  0.2977026402950287
# Epoch:  480 Loss value:  0.26630154252052307
# Epoch:  490 Loss value:  0.2518894672393799

# %% [markdown]
# # Using different optimizer -SGD

# %%
model = CropRecommendationModelMoreNeurons()

optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# %%
run = wandb.init(
    # Set the wandb entity where your project will be logged (generally your team name).
    entity="aishwaryapatil845-aish-com",
    # Set the wandb project where this run will be logged.
    project="Crop_Recommendation",
    name="Model-epoch-500-SGD",
    # Track hyperparameters and run metadata.
    config={
        "learning_rate": 0.001,
        "momentum": 0.9,
        "architecture": "FNN",
        "dataset": "crop_recommndation",
        "epochs": 500,
    },
)

# Training loop 
epoches = 500

for epoch in range(epoches):
    model.train()

    out = model(X_train)
    loss = loss_function(out, y_train)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # accuracy
    model.eval()
    y_pred = model(X_test).argmax(dim=1)
    acc = accuracy_score(y_test, y_pred)

    if epoch % 10 == 0 :
        print("Epoch: ", epoch, "Loss value: ", loss.item())
        run.log({"loss": loss.item(), "epoch": epoch, "accuracy": acc})
# Out:
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▁▁▁▁▄▄▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇██████████████████</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>███▇▆▅▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.94318</td></tr><tr><td>epoch</td><td>490</td></tr><tr><td>loss</td><td>0.25189</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Model-epoch-500-more-neurons</strong> at: <a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation/runs/aosnuam5' target="_blank">https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation/runs/aosnuam5</a><br> View project at: <a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation' target="_blank">https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260306_123948-aosnuam5/logs</code>
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/home/aishwarya/Downloads/Notes/PyTorch_Notes/Notebooks/wandb/run-20260306_124527-grkzzseg</code>
# Syncing run <strong><a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation/runs/grkzzseg' target="_blank">Model-epoch-500-SGD</a></strong> to <a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation' target="_blank">https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation</a>
#  View run at <a href='https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation/runs/grkzzseg' target="_blank">https://wandb.ai/aishwaryapatil845-aish-com/Crop_Recommendation/runs/grkzzseg</a>
# Epoch:  0 Loss value:  3.09574031829834
# Epoch:  10 Loss value:  3.095754623413086
# Epoch:  20 Loss value:  3.094839096069336
# Epoch:  30 Loss value:  3.0953896045684814
# Epoch:  40 Loss value:  3.0955963134765625
# Epoch:  50 Loss value:  3.095043182373047
# Epoch:  60 Loss value:  3.095336675643921
# Epoch:  70 Loss value:  3.094695806503296
# Epoch:  80 Loss value:  3.0952813625335693
# Epoch:  90 Loss value:  3.0944674015045166
# Epoch:  100 Loss value:  3.094524383544922
# Epoch:  110 Loss value:  3.094365358352661
# Epoch:  120 Loss value:  3.0949013233184814
# Epoch:  130 Loss value:  3.0942022800445557
# Epoch:  140 Loss value:  3.0949060916900635
# Epoch:  150 Loss value:  3.0946500301361084
# Epoch:  160 Loss value:  3.0943875312805176
# Epoch:  170 Loss value:  3.093703508377075
# Epoch:  180 Loss value:  3.094310998916626
# Epoch:  190 Loss value:  3.0940537452697754
# Epoch:  200 Loss value:  3.0940821170806885
# Epoch:  210 Loss value:  3.0938727855682373
# Epoch:  220 Loss value:  3.0940427780151367
# Epoch:  230 Loss value:  3.0939199924468994
# Epoch:  240 Loss value:  3.093867540359497
# Epoch:  250 Loss value:  3.093904733657837
# Epoch:  260 Loss value:  3.093930959701538
# Epoch:  270 Loss value:  3.093968629837036
# Epoch:  280 Loss value:  3.0937387943267822
# Epoch:  290 Loss value:  3.093311071395874
# Epoch:  300 Loss value:  3.093407154083252
# Epoch:  310 Loss value:  3.09335994720459
# Epoch:  320 Loss value:  3.093153238296509
# Epoch:  330 Loss value:  3.093360185623169
# Epoch:  340 Loss value:  3.0932888984680176
# Epoch:  350 Loss value:  3.0933570861816406
# Epoch:  360 Loss value:  3.0930750370025635
# Epoch:  370 Loss value:  3.0929272174835205
# Epoch:  380 Loss value:  3.093137502670288
# Epoch:  390 Loss value:  3.0928447246551514
# Epoch:  400 Loss value:  3.0923800468444824
# Epoch:  410 Loss value:  3.092726230621338
# Epoch:  420 Loss value:  3.0927839279174805
# Epoch:  430 Loss value:  3.0925254821777344
# Epoch:  440 Loss value:  3.092550277709961
# Epoch:  450 Loss value:  3.0929059982299805
# Epoch:  460 Loss value:  3.0923585891723633
# Epoch:  470 Loss value:  3.092784881591797
# Epoch:  480 Loss value:  3.0923218727111816
# Epoch:  490 Loss value:  3.0923044681549072

# %% [markdown]
# # Saving Model
# - The best model with the scaled data
# - Lets save scaled model

# %%
model = CropRecommendationModelReLU()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
# Training loop 
epoches = 501

for epoch in range(epoches):
    model.train()

    out = model(X_train)
    loss = loss_function(out, y_train)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # accuracy
    model.eval()
    y_pred = model(X_test).argmax(dim=1)
    acc = accuracy_score(y_test, y_pred)

    if epoch % 10 == 0 :
        print("Epoch: ", epoch, " Loss value: ", loss.item(), " Accuracy: ", acc)
# Out:
# Epoch:  0  Loss value:  3.0956883430480957  Accuracy:  0.05909090909090909
# Epoch:  10  Loss value:  3.075613021850586  Accuracy:  0.11136363636363636
# Epoch:  20  Loss value:  3.0427277088165283  Accuracy:  0.11818181818181818
# Epoch:  30  Loss value:  2.986079454421997  Accuracy:  0.15227272727272728
# Epoch:  40  Loss value:  2.874899387359619  Accuracy:  0.18181818181818182
# Epoch:  50  Loss value:  2.7138099670410156  Accuracy:  0.20454545454545456
# Epoch:  60  Loss value:  2.5181477069854736  Accuracy:  0.24772727272727274
# Epoch:  70  Loss value:  2.306511163711548  Accuracy:  0.3068181818181818
# Epoch:  80  Loss value:  2.0623977184295654  Accuracy:  0.42727272727272725
# Epoch:  90  Loss value:  1.8253499269485474  Accuracy:  0.4954545454545455
# Epoch:  100  Loss value:  1.6318392753601074  Accuracy:  0.5522727272727272
# Epoch:  110  Loss value:  1.4768187999725342  Accuracy:  0.6136363636363636
# Epoch:  120  Loss value:  1.3357040882110596  Accuracy:  0.6772727272727272
# Epoch:  130  Loss value:  1.2199827432632446  Accuracy:  0.7363636363636363
# Epoch:  140  Loss value:  1.0871087312698364  Accuracy:  0.7681818181818182
# Epoch:  150  Loss value:  1.0197899341583252  Accuracy:  0.8045454545454546
# Epoch:  160  Loss value:  0.9391739368438721  Accuracy:  0.8113636363636364
# Epoch:  170  Loss value:  0.8467421531677246  Accuracy:  0.8318181818181818
# Epoch:  180  Loss value:  0.8073984980583191  Accuracy:  0.8454545454545455
# Epoch:  190  Loss value:  0.753427267074585  Accuracy:  0.8568181818181818
# Epoch:  200  Loss value:  0.714442789554596  Accuracy:  0.8727272727272727
# Epoch:  210  Loss value:  0.6813705563545227  Accuracy:  0.8909090909090909
# Epoch:  220  Loss value:  0.6381961703300476  Accuracy:  0.8886363636363637
# Epoch:  230  Loss value:  0.5992602705955505  Accuracy:  0.8909090909090909
# Epoch:  240  Loss value:  0.5682854652404785  Accuracy:  0.8886363636363637
# Epoch:  250  Loss value:  0.544377326965332  Accuracy:  0.8954545454545455
# Epoch:  260  Loss value:  0.5441359281539917  Accuracy:  0.9068181818181819
# Epoch:  270  Loss value:  0.49909988045692444  Accuracy:  0.8977272727272727
# Epoch:  280  Loss value:  0.49927887320518494  Accuracy:  0.9022727272727272
# Epoch:  290  Loss value:  0.4872485399246216  Accuracy:  0.9136363636363637
# Epoch:  300  Loss value:  0.46004968881607056  Accuracy:  0.9090909090909091
# Epoch:  310  Loss value:  0.42984047532081604  Accuracy:  0.9204545454545454
# Epoch:  320  Loss value:  0.42385879158973694  Accuracy:  0.9204545454545454
# Epoch:  330  Loss value:  0.43287286162376404  Accuracy:  0.9227272727272727
# Epoch:  340  Loss value:  0.40316158533096313  Accuracy:  0.9227272727272727
# Epoch:  350  Loss value:  0.42934468388557434  Accuracy:  0.9295454545454546
# Epoch:  360  Loss value:  0.4112365245819092  Accuracy:  0.9318181818181818
# Epoch:  370  Loss value:  0.358366459608078  Accuracy:  0.9272727272727272
# Epoch:  380  Loss value:  0.376276433467865  Accuracy:  0.9272727272727272
# Epoch:  390  Loss value:  0.35150933265686035  Accuracy:  0.9295454545454546
# Epoch:  400  Loss value:  0.35827380418777466  Accuracy:  0.9340909090909091
# Epoch:  410  Loss value:  0.3176451325416565  Accuracy:  0.9318181818181818
# Epoch:  420  Loss value:  0.3121407628059387  Accuracy:  0.9409090909090909
# Epoch:  430  Loss value:  0.33010244369506836  Accuracy:  0.9340909090909091
# Epoch:  440  Loss value:  0.3188196122646332  Accuracy:  0.9454545454545454
# Epoch:  450  Loss value:  0.3202580511569977  Accuracy:  0.9431818181818182
# Epoch:  460  Loss value:  0.29181399941444397  Accuracy:  0.9431818181818182
# Epoch:  470  Loss value:  0.30491551756858826  Accuracy:  0.9477272727272728
# Epoch:  480  Loss value:  0.273995578289032  Accuracy:  0.9477272727272728
# Epoch:  490  Loss value:  0.2796081602573395  Accuracy:  0.95
# Epoch:  500  Loss value:  0.3012305498123169  Accuracy:  0.9477272727272728

# %%
from sklearn.metrics import classification_report

# %%
X_test
# Out:
# tensor([[ 1.3668, -1.1026, -0.0227,  ...,  1.0444, -0.3676, -1.4042],
#         [ 1.2855, -1.3755,  0.0563,  ...,  0.6757, -0.2716, -0.9834],
#         [ 0.2289,  0.2619,  0.0168,  ...,  0.9825,  0.6100,  0.2059],
#         ...,
#         [ 1.9087, -0.1929, -0.6349,  ...,  0.3511,  1.6203, -0.5636],
#         [ 1.7732, -0.0413, -0.5757,  ...,  0.1748, -0.4587, -0.6622],
#         [-1.2342,  0.4438, -0.5559,  ..., -1.7240, -0.4495,  0.9447]])

# %%
y_pred = model(X_test).argmax(dim=1)
y_pred
# Out:
# tensor([15, 21, 17, 17,  0, 12,  0, 13, 14, 10,  2,  4, 19,  8,  4, 19,  0, 11,
#         17, 15,  5, 17, 16, 17,  3,  8, 14, 16, 18, 20, 19, 10,  8, 10,  8,  2,
#          8,  3,  3,  3, 17, 12,  2, 11, 14, 11, 18,  4, 15, 11,  2,  5,  7, 14,
19
#           21       1.00      1.00      1.00        19
#
#     accuracy                           0.95       440
#    macro avg       0.95      0.95      0.94       440
# weighted avg       0.95      0.95      0.95       440

# %%
X.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall'], dtype='str')

# %%
import numpy as np

# %%
user_X = np.array([[100, 112, 130, 45, 100, 7, 100]])
user_X_tensors = torch.tensor(user_X, dtype=torch.float)

scaler.fit_transform(user_X_tensors)
# Out:
# array([[0., 0., 0., 0., 0., 0., 0.]])

# %%
model(user_X_tensors).argmax(dim=1)
# Out:
# tensor([0])

# %%
label_names[0]
# Out:
# 'cotton'

# %% [markdown]
# - saving our model using safetensors

# %%
# !uv add safetensors
# Out:
# Resolved 23 packages in 1.39s
# Prepared 1 package in 697ms
# Installed 1 package in 4ms
#  + safetensors==0.7.0

# %%
from safetensors.torch import save_file

# %%
model
# Out:
# CropRecommendationModelReLU(
#   (fc1): Linear(in_features=7, out_features=14, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=14, out_features=28, bias=True)
#   (relu2): ReLU()
#   (do1): Dropout(p=0.2, inplace=False)
#   (fc3): Linear(in_features=28, out_features=56, bias=True)
#   (relu3): ReLU()
#   (do2): Dropout(p=0.2, inplace=False)
#   (fc4): Linear(in_features=56, out_features=34, bias=True)
#   (relu4): ReLU()
#   (do3): Dropout(p=0.1, inplace=False)
#   (fc5): Linear(in_features=34, out_features=22, bias=True)
# )

# %% [markdown]
# - print all layers weights and biases using `.state_dict()`

# %%
model.state_dict()
# Out:
# OrderedDict([('fc1.weight',
#               tensor([[-0.2111,  0.2640,  0.1059,  0.3019, -0.5774,  0.0949, -0.3287],
#                       [ 0.5342,  0.2489, -0.3143, -0.1934, -0.2043, -0.1657,  0.3539],
#                       [-0.0987,  0.0512,  0.1112, -0.4442, -0.5137,  0.1988, -0.6578],
#                       [ 0.3090,  0.3631,  0.1529,  0.0749,  0.7331,  0.0367,  0.1350],
#                       [-0.0265,  0.5092,  0.0579, -0.3406,  0.4989, -0.1896,  0.5193],
#                       [ 0.0211, -0.1412, -0.8118,  0.0179,  0.1731,  0.0084, -0.5765],
#                       [ 0.2999,  0.4515,  0.4202,  0.3438,  0.0781,  0.0360,  0.1128],
#                       [-0.4441,  0.3580,  0.0292, -0.0565, -0.4620, -0.2939,  0.1981],
#                       [-0.1167,  0.7132,  0.0020,  0.1216,  0.2457, -0.0202, -0.1981],
#                       [-0.1079, -0.6614,  0.0777,  0.0875,  0.2595, -0.3969, -0.4950],
#                       [-0.5201,  0.3542, -0.5107,  0.0942,  0.7402,  0.0195,  0.0848],
#                       [-0.1501,  0.2259,  0.0337,  0.4586,  0.3139,  0.2341, -0.4680],
#                       [-0.1404,  0.2331, -0.4775, -0.4176, -0.1677, -0.0721, -0.2596],
#                       [ 0.3117,  0.5362, -0.5501, -0.1099,  0.2543, -0.1459, -0.5055]])),
#              ('fc1.bias',
#               tensor([ 0.4469,  0.2185, -0.3645,  0.0142,  0.1343, -0.1826,  0.3933,  0.1380,
#                        0.3635,  0.2131,  0.2194,  0.1017,  0.5438,  0.4990])),
#              ('fc2.weight',
#               tensor([[-5.2638e-01, -2.5912e-01, -2.4427e-02,  5.2095e-01,  2.1916e-01,
#                        -2.5193e-01,  6.3306e-02, -4.3505e-01, -2.5599e-01,  2.0097e-01,
#                         5.2594e-01,  2.6560e-01, -5.1939e-02, -1.2425e-01],
#                        -0.0261,  0.1539],
#                       [ 0.0805,  0.1557, -0.1640,  0.1349, -0.3301, -0.2158,  0.0300,  0.1059,
#                        -0.1238,  0.1532, -0.0690, -0.0567, -0.0485,  0.0021, -0.1514,  0.1183,
#                         0.1804, -0.1236,  0.2353,  0.1628, -0.2807,  0.1433, -0.2198, -0.1532,
#                        -0.0890,  0.2745,  0.0714, -0.1785,  0.2267, -0.3036, -0.2223, -0.2035,
#                         0.1308,  0.1668],
#                       [-0.2322, -0.2171, -0.2395, -0.3768,  0.1853,  0.2721, -0.5577, -0.6452,
#                        -0.4779,  0.3626, -0.4741, -0.2792,  0.1765,  0.0922,  0.1699, -0.0498,
#                         0.2825,  0.2406,  0.2476, -0.1791,  0.3044, -0.5054, -0.4129,  0.1316,
#                        -0.0047, -0.3081, -0.3663,  0.2442, -0.2341,  0.2496, -0.3317,  0.2972,
#                        -0.3811, -0.0449],
#                       [-0.3031, -0.0434,  0.2130, -0.3012, -0.3124,  0.0633, -0.1514, -0.0627,
#                         0.2461,  0.1544, -0.3497, -0.2449, -0.2602, -0.1591, -0.0663,  0.0034,
#                         0.2406, -0.3234,  0.1176,  0.2696,  0.1691,  0.1875,  0.3283,  0.2582,
#                        -0.2339, -0.1904, -0.4090, -0.0964,  0.1167, -0.1616, -0.1797,  0.2758,
#                         0.0301,  0.1250],
#                       [-0.2884, -0.0469, -0.2041, -0.2778,  0.1727,  0.1461,  0.1061, -0.4014,
#                         0.1445,  0.2214,  0.2346, -0.1038,  0.1501, -0.3917,  0.2658, -0.3861,
#                        -0.3325, -0.2953, -0.0840, -0.3450,  0.2862, -0.1992,  0.2578,  0.3355,
#                         0.2222, -0.2349,  0.0130, -0.2830, -0.2701,  0.2047, -0.2088,  0.1553,
#                        -0.3938, -0.2209]])),
#              ('fc5.bias',
#               tensor([-0.0875, -0.2991,  0.3926,  0.0409,  0.1068,  0.1275, -0.1766, -0.2001,
#                        0.1210, -0.1828, -0.2650, -0.0021,  0.3420,  0.0652,  0.0026, -0.2561,
#                        0.0513,  0.1469,  0.1025,  0.1907, -0.1172,  0.3409]))])

# %%
tensors = model.state_dict()

# %%
save_file(tensors, "Models/crop_recommendation.safetensors")

# %% [markdown]
# ### Load save safetensors models

# %% [markdown]
# - First load model architecture

# %%
class CropRecommendationModelLoad(nn.Module):
    def __init__(self):
        super(CropRecommendationModelLoad, self).__init__()

        # layers
        self.fc1 = nn.Linear(7, 14)
        self.relu1 = nn.ReLU()
        
        # ------ hidden layer
        self.fc2 = nn.Linear(14, 28)
        self.relu2 = nn.ReLU()
        self.do1 = nn.Dropout(0.2)
        
        self.fc3 = nn.Linear(28, 56)
        self.relu3 = nn.ReLU()
        self.do2 = nn.Dropout(0.2)
        
        self.fc4 = nn.Linear(56, 34)
        self.relu4 = nn.ReLU()
        self.do3 = nn.Dropout(0.1)
        # -------
        self.fc5 = nn.Linear(34, 22) # output layer

    def forward(self, x):
        x = self.fc1(x) # input layer
        x = self.relu1(x)
        

        # hidden layer
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.do1(x)
        
        x = self.fc3(x)
        x = self.relu3(x)
        x = self.do2(x)
        
        x = self.fc4(x)
        x = self.relu4(x)
        x = self.do3(x)

        x = self.fc5(x) # output layer

        return x

# %%
loaded_model = CropRecommendationModelLoad()
loaded_model
# Out:
# CropRecommendationModelLoad(
#   (fc1): Linear(in_features=7, out_features=14, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=14, out_features=28, bias=True)
#   (relu2): ReLU()
#   (do1): Dropout(p=0.2, inplace=False)
#   (fc3): Linear(in_features=28, out_features=56, bias=True)
#   (relu3): ReLU()
#   (do2): Dropout(p=0.2, inplace=False)
#   (fc4): Linear(in_features=56, out_features=34, bias=True)
#   (relu4): ReLU()
#   (do3): Dropout(p=0.1, inplace=False)
#   (fc5): Linear(in_features=34, out_features=22, bias=True)
# )

# %%
from safetensors.torch import load_file

# %%
tensors = load_file("Models/crop_recommendation.safetensors")
tensors
# Out:
# {'fc1.bias': tensor([ 0.4469,  0.2185, -0.3645,  0.0142,  0.1343, -0.1826,  0.3933,  0.1380,
#           0.3635,  0.2131,  0.2194,  0.1017,  0.5438,  0.4990]),
#  'fc1.weight': tensor([[-0.2111,  0.2640,  0.1059,  0.3019, -0.5774,  0.0949, -0.3287],
#          [ 0.5342,  0.2489, -0.3143, -0.1934, -0.2043, -0.1657,  0.3539],
#          [-0.0987,  0.0512,  0.1112, -0.4442, -0.5137,  0.1988, -0.6578],
#          [ 0.3090,  0.3631,  0.1529,  0.0749,  0.7331,  0.0367,  0.1350],
#          [-0.0265,  0.5092,  0.0579, -0.3406,  0.4989, -0.1896,  0.5193],
#          [ 0.0211, -0.1412, -0.8118,  0.0179,  0.1731,  0.0084, -0.5765],
#          [ 0.2999,  0.4515,  0.4202,  0.3438,  0.0781,  0.0360,  0.1128],
#          [-0.4441,  0.3580,  0.0292, -0.0565, -0.4620, -0.2939,  0.1981],
#          [-0.1167,  0.7132,  0.0020,  0.1216,  0.2457, -0.0202, -0.1981],
#          [-0.1079, -0.6614,  0.0777,  0.0875,  0.2595, -0.3969, -0.4950],
#          [-0.5201,  0.3542, -0.5107,  0.0942,  0.7402,  0.0195,  0.0848],
#          [-0.1501,  0.2259,  0.0337,  0.4586,  0.3139,  0.2341, -0.4680],
#          [-0.1404,  0.2331, -0.4775, -0.4176, -0.1677, -0.0721, -0.2596],
#          [ 0.3117,  0.5362, -0.5501, -0.1099,  0.2543, -0.1459, -0.5055]]),
#  'fc2.bias': tensor([ 0.2084, -0.3155,  0.1008, -0.0746, -0.4965,  0.4164,  0.5617,  0.4335,
#          -0.3739, -0.2354, -0.0505, -0.0923, -0.2931,  0.2643,  0.3657, -0.2179,
#          -0.3888,  0.2260, -0.2944, -0.2426, -0.0798,  0.1877,  0.1745, -0.0450,
#           0.3444, -0.3756,  0.2647,  0.0670]),
#  'fc2.weight': tensor([[-5.2638e-01, -2.5912e-01, -2.4427e-02,  5.2095e-01,  2.1916e-01,
#           -2.5193e-01,  6.3306e-02, -4.3505e-01, -2.5599e-01,  2.0097e-01,
#            5.2594e-01,  2.6560e-01, -5.1939e-02, -1.2425e-01],
#          [ 1.4605e-02,  1.7610e-01, -1.2075e-02, -1.2849e-01, -4.2089e-01,
#           -0.4779,  0.3626, -0.4741, -0.2792,  0.1765,  0.0922,  0.1699, -0.0498,
#            0.2825,  0.2406,  0.2476, -0.1791,  0.3044, -0.5054, -0.4129,  0.1316,
#           -0.0047, -0.3081, -0.3663,  0.2442, -0.2341,  0.2496, -0.3317,  0.2972,
#           -0.3811, -0.0449],
#          [-0.3031, -0.0434,  0.2130, -0.3012, -0.3124,  0.0633, -0.1514, -0.0627,
#            0.2461,  0.1544, -0.3497, -0.2449, -0.2602, -0.1591, -0.0663,  0.0034,
#            0.2406, -0.3234,  0.1176,  0.2696,  0.1691,  0.1875,  0.3283,  0.2582,
#           -0.2339, -0.1904, -0.4090, -0.0964,  0.1167, -0.1616, -0.1797,  0.2758,
#            0.0301,  0.1250],
#          [-0.2884, -0.0469, -0.2041, -0.2778,  0.1727,  0.1461,  0.1061, -0.4014,
#            0.1445,  0.2214,  0.2346, -0.1038,  0.1501, -0.3917,  0.2658, -0.3861,
#           -0.3325, -0.2953, -0.0840, -0.3450,  0.2862, -0.1992,  0.2578,  0.3355,
#            0.2222, -0.2349,  0.0130, -0.2830, -0.2701,  0.2047, -0.2088,  0.1553,
#           -0.3938, -0.2209]])}

# %%
loaded_model.load_state_dict(tensors)
# Out:
# <All keys matched successfully>

# %%
loaded_model.eval()

y_pred = loaded_model(X_test).argmax(dim=1)
acc = accuracy_score(y_test, y_pred)

# %%
acc
# Out:
# 0.9477272727272728

# %%
# Training loop 
epoches = 101

for epoch in range(epoches):
    loaded_model.train()

    out = loaded_model(X_train)
    loss = loss_function(out, y_train)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # accuracy
    loaded_model.eval()
    y_pred = loaded_model(X_test).argmax(dim=1)
    acc = accuracy_score(y_test, y_pred)

    if epoch % 10 == 0 :
        print("Epoch: ", epoch, " Loss value: ", loss.item(), " Accuracy: ", acc)
# Out:
# Epoch:  0  Loss value:  0.2816063165664673  Accuracy:  0.9477272727272728
# Epoch:  10  Loss value:  0.27972960472106934  Accuracy:  0.9477272727272728
# Epoch:  20  Loss value:  0.2761676013469696  Accuracy:  0.9477272727272728
# Epoch:  30  Loss value:  0.272148996591568  Accuracy:  0.9477272727272728
# Epoch:  40  Loss value:  0.2679167091846466  Accuracy:  0.9477272727272728
# Epoch:  50  Loss value:  0.2637617588043213  Accuracy:  0.9477272727272728
# Epoch:  60  Loss value:  0.24940131604671478  Accuracy:  0.9477272727272728
# Epoch:  70  Loss value:  0.2827868163585663  Accuracy:  0.9477272727272728
# Epoch:  80  Loss value:  0.2593800127506256  Accuracy:  0.9477272727272728
# Epoch:  90  Loss value:  0.27890193462371826  Accuracy:  0.9477272727272728
# Epoch:  100  Loss value:  0.28055354952812195  Accuracy:  0.9477272727272728

# %% [markdown]
# ## Deploying model on hugging face

# %%
# !uv add huggingface_hub
# Out:
# Resolved 39 packages in 2ms
# Audited 37 packages in 0.53ms

# %%
# !huggingface-cli login
# Out:
# /bin/bash: line 1: huggingface-cli: command not found

# %%
from huggingface_hub import login

# %%
login()

# %%
from huggingface_hub import HfApi, create_repo

# %%
api = HfApi()

# %%
# create a repo for our model on hugging face
create_repo(repo_id="Aishwarya240/Crop_Recommendation_Model", repo_type="model", exist_ok=True)
# Out:
# RepoUrl('https://huggingface.co/Aishwarya240/Crop_Recommendation_Model', endpoint='https://huggingface.co', repo_type='model', repo_id='Aishwarya240/Crop_Recommendation_Model')

# %%
api.upload_file(
    path_or_fileobj="Models/crop_recommendation.safetensors",
    path_in_repo="crop_recommendation.safetensors",
    repo_id="Aishwarya240/Crop_Recommendation_Model",
    repo_type="model",
)
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/Aishwarya240/Crop_Recommendation_Model/commit/d054d8d20accc01e956e765a5ce6d63dfbafaca3', commit_message='Upload crop_recommendation.safetensors with huggingface_hub', commit_description='', oid='d054d8d20accc01e956e765a5ce6d63dfbafaca3', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Aishwarya240/Crop_Recommendation_Model', endpoint='https://huggingface.co', repo_type='model', repo_id='Aishwarya240/Crop_Recommendation_Model'), pr_revision=None, pr_num=None)

# %% [markdown]
# ## Using uploaded huggingface model

# %%
from huggingface_hub import hf_hub_download

# %%
file_path = hf_hub_download(repo_id="Sakib-Dalal/Crop_Recommendation_model", filename="crop_recommendation.safetensors")
# Out:
# crop_recommendation.safetensors:   0%|          | 0.00/20.2k [00:00<?, ?B/s]

# %%
file_path
# Out:
# '/home/aishwarya/.cache/huggingface/hub/models--Sakib-Dalal--Crop_Recommendation_model/snapshots/745702e83ffd74ff7e0d8335fff82b0f17bfaa01/crop_recommendation.safetensors'

# %%
from safetensors.torch import load_file

# %%
tensors = load_file(file_path)

# %%
tensors
# Out:
# {'fc1.bias': tensor([ 0.1682,  0.2715,  0.3995,  0.0408,  0.6122,  0.2638, -0.3094, -0.3033,
#           0.4330,  0.0684, -0.0122, -0.0788,  0.6186,  0.5966]),
#  'fc1.weight': tensor([[-0.4099,  0.1586, -0.1997, -0.0978,  0.5617, -0.1307,  0.5204],
#          [-0.2615,  0.3210,  0.1499,  0.0720, -0.2259, -0.4872, -0.5836],
#          [-0.3312,  0.1528, -0.8624, -0.0855, -0.1428, -0.0802, -0.2462],
#          [-0.2278, -0.2462, -0.5358,  0.0399, -0.5327, -0.0098,  0.5400],
#          [-0.1217, -0.1039,  0.4865, -0.1106,  0.5684, -0.1610, -0.1555],
#          [-0.0585, -0.0673,  0.4725,  0.6143, -0.1365,  0.1546, -0.3258],
#          [ 0.3914, -0.2846,  0.1439,  0.1654,  0.3906,  0.1638, -0.6746],
#          [-0.2153, -0.2979, -0.5354, -0.0987,  0.2251, -0.0177,  0.0010],
#          [-0.1484, -0.0718, -0.7016, -0.0033,  0.3152,  0.2956, -0.0331],
#          [-0.2977, -0.6102, -0.0704,  0.2466, -0.0431, -0.4303, -0.0941],
#          [ 0.5524, -0.3058, -0.0865, -0.0255, -0.1212,  0.1358, -0.0978],
#          [-0.2026,  0.1682,  0.4287, -0.2389, -0.5240,  0.3113, -0.4663],
#          [ 0.2653, -0.1294, -0.7108, -0.2422, -0.2852, -0.2151,  0.4630],
#           -3.3935e-01, -5.7642e-02, -2.1421e-01, -3.8092e-01, -3.7839e-02,
#           -2.9063e-01, -1.4047e-01, -2.3673e-01,  2.8904e-01,  2.9825e-01,
#            5.2332e-02,  2.9997e-01, -1.0717e-01, -1.8112e-01,  3.2265e-01,
#            6.4230e-02,  3.6300e-02,  2.1088e-02, -3.7735e-01,  5.3806e-02,
#           -3.9711e-01, -2.6458e-02,  1.2984e-01, -2.9994e-01, -1.9830e-01,
#            1.5127e-01,  2.3321e-01,  2.0210e-01, -3.7146e-01]])}

# %%
class CropRecommendationModelSakib(nn.Module):
    def __init__(self):
        super(CropRecommendationModelSakib, self).__init__()

        # layers
        self.fc1 = nn.Linear(7, 14)
        self.relu1 = nn.ReLU()
        
        # ------ hidden layer
        self.fc2 = nn.Linear(14, 28)
        self.relu2 = nn.ReLU()
        self.do1 = nn.Dropout(0.2)
        
        self.fc3 = nn.Linear(28, 56)
        self.relu3 = nn.ReLU()
        self.do2 = nn.Dropout(0.2)
        
        self.fc4 = nn.Linear(56, 34)
        self.relu4 = nn.ReLU()
        self.do3 = nn.Dropout(0.1)
        # -------
        self.fc5 = nn.Linear(34, 22) # output layer

    def forward(self, x):
        x = self.fc1(x) # input layer
        x = self.relu1(x)
        

        # hidden layer
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.do1(x)
        
        x = self.fc3(x)
        x = self.relu3(x)
        x = self.do2(x)
        
        x = self.fc4(x)
        x = self.relu4(x)
        x = self.do3(x)

        x = self.fc5(x) # output layer

        return x

# %%
model = CropRecommendationModelSakib()
model
# Out:
# CropRecommendationModelSakib(
#   (fc1): Linear(in_features=7, out_features=14, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=14, out_features=28, bias=True)
#   (relu2): ReLU()
#   (do1): Dropout(p=0.2, inplace=False)
#   (fc3): Linear(in_features=28, out_features=56, bias=True)
#   (relu3): ReLU()
#   (do2): Dropout(p=0.2, inplace=False)
#   (fc4): Linear(in_features=56, out_features=34, bias=True)
#   (relu4): ReLU()
#   (do3): Dropout(p=0.1, inplace=False)
#   (fc5): Linear(in_features=34, out_features=22, bias=True)
# )

# %%
model.load_state_dict(tensors)
# Out:
# <All keys matched successfully>

# %%
y_pred = model(X_test).argmax(dim=1)
acc= accuracy_score(y_test, y_pred)

# %%
acc
# Out:
# 0.8818181818181818

# %% [markdown]
# - Lets retrain sakib model

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_function = nn.CrossEntropyLoss()

# %%
# Training loop 
epoches = 101

for epoch in range(epoches):
    model.train()

    out = loaded_model(X_train)
    loss = loss_function(out, y_train)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # accuracy
    model.eval()
    y_pred = model(X_test).argmax(dim=1)
    acc = accuracy_score(y_test, y_pred)

    if epoch % 10 == 0 :
        print("Epoch: ", epoch, " Loss value: ", loss.item(), " Accuracy: ", acc)
# Out:
# Epoch:  0  Loss value:  0.08622344583272934  Accuracy:  0.9613636363636363
# Epoch:  10  Loss value:  0.08622344583272934  Accuracy:  0.9613636363636363
# Epoch:  20  Loss value:  0.08622344583272934  Accuracy:  0.9613636363636363
# Epoch:  30  Loss value:  0.08622344583272934  Accuracy:  0.9613636363636363
# Epoch:  40  Loss value:  0.08622344583272934  Accuracy:  0.9613636363636363
# Epoch:  50  Loss value:  0.08622344583272934  Accuracy:  0.9613636363636363
# Epoch:  60  Loss value:  0.08622344583272934  Accuracy:  0.9613636363636363
# Epoch:  70  Loss value:  0.08622344583272934  Accuracy:  0.9613636363636363
# Epoch:  80  Loss value:  0.08622344583272934  Accuracy:  0.9613636363636363
# Epoch:  90  Loss value:  0.08622344583272934  Accuracy:  0.9613636363636363
# Epoch:  100  Loss value:  0.08622344583272934  Accuracy:  0.9613636363636363

# %%
y_pred = model(X_test).argmax(dim=1)
acc = accuracy_score(y_test, y_pred)

# %%
acc
# Out:
# 0.9613636363636363
