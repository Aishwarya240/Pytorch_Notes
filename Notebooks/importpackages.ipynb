# %%
import numpy as np

# %%
import pandas as pd

# %%
import torch

# %%
import matplotlib

# %%
import sklearn

# %%
torch.__version__
# Out:
# '2.10.0+cu128'

# %%
sklearn.__version__
# Out:
# '1.8.0'

# %%
matplotlib.__version__
# Out:
# '3.10.8'

# %%
pd.__version__
# Out:
# '3.0.1'
