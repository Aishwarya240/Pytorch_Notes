# %%
import numpy as np

# %%
import pandas as pd

# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import torch
#
# ModuleNotFoundError: No module named 'torch'
